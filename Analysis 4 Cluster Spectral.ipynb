# %% [markdown]
# # The Future is Now: Patterns in Global Temperature Trends Across the World
#
# Continued from `Analysis 3 Cluster Hierarchical.ipynb`.
#
# ## Dependency Installation & Imports

# %%
# %pip install pandas numpy scikit-learn matplotlib missingno pyarrow pycountry_convert kgcpy scipy fastdtw statsmodels networkx pyvis
# Out:
# Requirement already satisfied: pandas in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: matplotlib in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (3.8.3)
# Requirement already satisfied: missingno in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (0.5.2)
# Requirement already satisfied: pyarrow in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (15.0.2)
# Requirement already satisfied: pycountry_convert in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (0.7.2)
# Requirement already satisfied: kgcpy in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (1.1.3)
# Requirement already satisfied: scipy in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (1.12.0)
# Requirement already satisfied: fastdtw in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (0.3.4)
# Requirement already satisfied: statsmodels in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (0.14.1)
# Requirement already satisfied: networkx in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (3.2.1)
# Requirement already satisfied: pyvis in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (0.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: pillow>=8 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: seaborn in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: pytest>=3.4.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pycountry_convert) (8.1.1)
# Requirement already satisfied: pytest-cov>=2.5.1 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pycountry_convert) (5.0.0)
# Requirement already satisfied: wheel>=0.30.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pycountry_convert) (0.43.0)
# Requirement already satisfied: pycountry>=16.11.27.1 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pycountry_convert) (23.12.11)
# Requirement already satisfied: pprintpp>=0.3.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pycountry_convert) (0.4.0)
# Requirement already satisfied: repoze.lru>=0.7 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pycountry_convert) (0.7)
# Requirement already satisfied: pytest-mock>=1.6.3 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pycountry_convert) (3.14.0)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pyvis) (3.0.3)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pyvis) (8.22.2)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pyvis) (3.1.3)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (2.17.2)
# Requirement already satisfied: colorama in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.6)
# Requirement already satisfied: exceptiongroup in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (1.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.43)
# Requirement already satisfied: decorator in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.19.1)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (5.14.2)
# Requirement already satisfied: matplotlib-inline in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from jinja2>=2.9.6->pyvis) (2.1.5)
# Requirement already satisfied: six in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)
# Requirement already satisfied: pluggy<2.0,>=1.4 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.4.0)
# Requirement already satisfied: tomli>=1 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (2.0.1)
# Requirement already satisfied: iniconfig in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (2.0.0)
# Requirement already satisfied: coverage[toml]>=5.2.1 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from pytest-cov>=2.5.1->pycountry_convert) (7.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.1)
# Requirement already satisfied: pure-eval in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jacob\dropbox\2024 spring\cs 457 datamining\temperature patterns\.venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.4.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from fastdtw import fastdtw
from sklearn.cluster import DBSCAN
from sklearn.manifold import MDS
from sklearn.metrics import silhouette_score
from sklearn.neighbors import NearestNeighbors
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist, squareform
from scipy.spatial.distance import euclidean
from scipy.stats import linregress
from dtaidistance import dtw

# %%
pd.set_option('display.max_rows', 12)
pd.set_option('display.max_columns', 12)
global_correlation = 0.895059831369191

# %% [markdown]
# ## Further Pattern Examination
#
# ### Data Preparation (Standardization)

# %%
with open('Data_augmented.csv', 'r', encoding='utf-8') as file:
    df = pd.read_csv(file, encoding='utf-8')

df = df.drop(['Latitude', 'Longitude', 'AbsLatitude', 'AbsLongitude'], axis=1)

df.head()
# Out:
#        City  Year  AverageTemperature Country  NumericLatitude  \
# 0  A Coruña  1880           12.837750   Spain            42.59
# 1  A Coruña  1881           13.405000   Spain            42.59
# 2  A Coruña  1882           12.776250   Spain            42.59
# 3  A Coruña  1883           12.260833   Spain            42.59
# 4  A Coruña  1884           12.693250   Spain            42.59
#
#    NumericLongitude Continent  kcc
# 0             -8.73    Europe  Csb
# 1             -8.73    Europe  Csb
# 2             -8.73    Europe  Csb
# 3             -8.73    Europe  Csb
# 4             -8.73    Europe  Csb

# %% [markdown]
# ### Density-Based Clustering
#
# Using DBSCAN

# %%
from sklearn.preprocessing import StandardScaler

def calc_corr(group):
    return group['AverageTemperature'].corr(group['Year'])

correlations = df.groupby('City').apply(calc_corr)

# Prepare the data for clustering
clustering_data = pd.DataFrame(correlations, columns=['Correlation']).reset_index()
# Merge back with the original DataFrame to get latitude and longitude
clustering_data = clustering_data.merge(df[['City', 'NumericLatitude', 'NumericLongitude']].drop_duplicates(), on='City')

# Standardize features by removing the mean and scaling to unit variance
scaler = StandardScaler()
clustering_data_scaled = scaler.fit_transform(clustering_data[['Correlation', 'NumericLatitude', 'NumericLongitude']])
# Out:
# C:\Users\jacob\AppData\Local\Temp\ipykernel_19384\869047953.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   correlations = df.groupby('City').apply(calc_corr)

# %%
X = clustering_data_scaled

n_neighbors = 70 # rule of thumb: range of 2-5% of data points
nearest_neighbors = NearestNeighbors(n_neighbors=n_neighbors)
nearest_neighbors.fit(X)
distances, indices = nearest_neighbors.kneighbors(X)

sorted_distances = np.sort(distances[:, n_neighbors-1], axis=0)

plt.figure(figsize=(12,8))
plt.plot(sorted_distances)
plt.xlabel("Points sorted by distance to the n-th nearest neighbor")
plt.ylabel(f"{n_neighbors-1}-th nearest neighbor distance")
plt.title("Trying to find optimal Eps using nearest neighbors")
plt.show()

# %%
elbow_index = 1300
eps_value = sorted_distances[elbow_index] # determined from the plot
print(f'eps value is: {eps_value}')
min_samples_value = 5

dbscan = DBSCAN(eps=eps_value, min_samples=min_samples_value).fit(combined_features)
labels = dbscan.labels_

# Analyzing the clustering results
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print(f'Estimated number of clusters: {n_clusters_}')
print(f'Estimated number of noise points: {n_noise_}')
# Out:
# eps value is: 0.2948152003041518
# Estimated number of clusters: 7
# Estimated number of noise points: 50

# %%
X = matrix_cities

n_neighbors = 120 # rule of thumb: range of 2-5% of data points
nearest_neighbors = NearestNeighbors(n_neighbors=n_neighbors)
nearest_neighbors.fit(X)
distances, indices = nearest_neighbors.kneighbors(X)

sorted_distances = np.sort(distances[:, n_neighbors-1], axis=0)

plt.figure(figsize=(12,8))
plt.plot(sorted_distances)
plt.xlabel("Points sorted by distance to the n-th nearest neighbor")
plt.ylabel(f"{n_neighbors-1}-th nearest neighbor distance")
plt.title("Trying to find optimal Eps using nearest neighbors")
plt.show()

# %% [markdown]
# Based on this information (retrieved by making modifications to the `elbow_index` value in cell below), it looks like an eps from 12.18 to 12.8 is a good sweet spot, i.e. an elbow index of 40 to 45. I will be using 43 for DBSCAN.

# %% [markdown]
# 1. Choose Parameters eps and min_samples:
#    * eps: The maximum distance between two samples for them to be considered in the same neighborhood.
#    * min_samples: The number of samples in a neighborhood for a point to be considered a core point.
#
# DBSCAN labels each point with a cluster label or -1 for noise/outliers.
#
# Comparing to k-means and Hierarchical:
# * Cluster Quality: Evaluate using silhouette scores, noting that DBSCAN may produce a "noise" category (-1 label) for outliers.
# * Robustness to Outliers: DBSCAN's ability to identify and exclude outliers may lead to more robust clustering than k-means or hierarchical clustering, especially if outliers distorted the k-means results.
# * Cluster Interpretation: Similarly, analyze the resulting clusters in terms of continents, KCC's relative abundance, and regression correlations, as with hierarchical clustering.

# %%
city_cluster_df = pd.DataFrame({'City': cities, 'Cluster': labels})

df_merged = pd.merge(df, city_cluster_df, on='City', how='left')

# %%
df_dbscan = df_merged.drop_duplicates(subset='City', keep='first')
df_dbscan = df_dbscan[['Country', 'NumericLatitude', 'NumericLongitude', 'Continent', 'kcc', 'City', 'Cluster']]
df_dbscan = df_dbscan.sort_values(by=['Cluster', 'City']).reset_index(drop=True)
outfile = 'Data_dbscan.csv'

df_dbscan.to_csv(f'{outfile}', index=False)

print(f'Exported dbscan cities to {outfile}')
# Out:
# Exported dbscan cities to Data_dbscan.csv

# %% [markdown]
# #### Cluster Visualizations
#
# ~~1. Unique Cities in each cluster~~
# ~~2. Unique Countries in each cluster~~
# 3. Proportion of Continents in each cluster relative to all data
#    1. Bar graph with absolute abundance
#    2. Heat map with relative abundance
# 4. Proportion of climates in each cluster relative to all data
#    1. Bar graph with absolute abundance
#    2. Heat map with relative abundance
# 5. For each cluster:
#    ~~1. Averaged AverageTemperature by Year & correlations~~
#    2. AverageTemperature by Year & correlations
#    3. Box & Whiskers plots to look at geographic spread (Latitude, Longitude)

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
cities_per_cluster = df_merged.groupby('Cluster')['City'].nunique()
cities_per_cluster.plot(kind='bar')
plt.title('Number of Unique Cities in Each Cluster')
plt.xlabel('Cluster')
plt.ylabel('Number of Cities')
for index, value in enumerate(cities_per_cluster):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.subplot(1, 2, 2)
countries_per_cluster = df_merged.groupby('Cluster')['Country'].nunique()
countries_per_cluster.plot(kind='bar')
plt.title('Number of Unique Countries in Each Cluster')
plt.xlabel('Cluster')
plt.ylabel('Number of Countries')
for index, value in enumerate(countries_per_cluster):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.tight_layout()
plt.show()

print('Cluster of -1 indicates noise points')
# Out:
# Cluster of -1 indicates noise points

# %% [markdown]
# Visualization & correlation of averaged clusters

# %%
city_profiles_standardized.reset_index(inplace=True)

n_clusters = np.sort(df_merged['Cluster'].unique())

for cluster in n_clusters:
    # Extract cities belonging to the current cluster
    cluster_cities = df_merged[df_merged['Cluster'] == cluster]['City'].unique()
    cluster_profiles = city_profiles_standardized[cluster_cities]

    mean_profile = cluster_profiles.mean(axis=1)

    plt.figure(figsize=(10, 6))
    plt.plot(city_profiles_standardized['Year'], mean_profile, label=f'Cluster {cluster}')

    # Line of best fit
    slope, intercept, r_value, _, _ = linregress(city_profiles_standardized['Year'].astype(float), mean_profile)
    line = slope * city_profiles_standardized['Year'].astype(float) + intercept
    plt.plot(city_profiles_standardized['Year'], line, 'r', label=f'Line of Best Fit: y={slope:.2f}x+{intercept:.2f}\n$r^2$={r_value**2:.2f}')

    cluster_label = 'Noise' if cluster == -1 else f'Cluster {cluster+1}'
    plt.title(f'Standardized Average Temperature Profile for {cluster_label}')
    plt.xlabel('Year')
    plt.ylabel('Standardized Average Temperature')
    plt.legend()
    plt.show()

# %% [markdown]
# Non-averaged clusters

# %%
for cluster in n_clusters:
    plt.figure(figsize=(12, 8))
    cluster_cities = df_merged[df_merged['Cluster'] == cluster]['City'].unique()

    for city in cluster_cities:
        city_profile = city_profiles_standardized[[city, 'Year']].dropna()
        plt.plot(city_profile['Year'], city_profile[city], label=city)

    cluster_label = 'Noise' if cluster == -1 else f'Cluster {cluster}'
    plt.title(f'Standardized Temperature Profile for {cluster_label}')
    plt.xlabel('Year')
    plt.ylabel('Standardized Average Temperature')

    # Place the legend outside the plot to the right
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust the rect to prevent cutting off the legend
    plt.show()

# %% [markdown]
# Relative abundance of continents

# %%
def add_labels(ax, values):
    for index, value in enumerate(values):
        ax.text(index, value, f"{value:.2f}", ha='center', va='bottom', fontsize=9, color='black')

n_clusters = len(np.sort(df_merged['Cluster'].unique()))

# Calculate grid size for subplots
n_rows = int(np.ceil(n_clusters / 3)) + 1  # Additional row for the overall data
fig, axs = plt.subplots(n_rows, 3, figsize=(18, n_rows * 7))
fig.subplots_adjust(hspace=0.6, wspace=0.4)

# Cluster continent abundance
for i, cluster in enumerate(np.sort(df_merged['Cluster'].unique())):
    ax = axs.flat[i]
    cluster_continent_abundance = df_merged[df_merged['Cluster'] == cluster]['Continent'].value_counts(normalize=True).sort_index()
    
    cluster_continent_abundance.plot(kind='bar', ax=ax, color=sns.color_palette("viridis", len(cluster_continent_abundance)))
    cluster_label = 'Noise' if cluster == -1 else f'Cluster {cluster+1}'
    ax.set_title(f'{cluster_label} - Continent Proportion')
    ax.set_ylabel('Proportion')
    ax.set_ylim(0, 1.2)
    add_labels(ax, cluster_continent_abundance.values)

# overall continent abundance
ax = axs.flat[n_clusters]
overall_continent_abundance = df['Continent'].value_counts(normalize=True).sort_index()
overall_continent_abundance.plot(kind='bar', ax=ax, color=sns.color_palette("viridis", len(overall_continent_abundance)))
ax.set_title('Overall - Continent Proportion')
ax.set_ylabel('Proportion')
ax.set_ylim(0, 1.2)
add_labels(ax, overall_continent_abundance.values)

# Hide any unused subplots
for i in range(n_clusters + 1, n_rows * 3):
    if i < len(axs.flat):
        fig.delaxes(axs.flat[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Relative abundance of Koppen climate classifications

# %%
n_rows = int(np.ceil(n_clusters / 3)) + 1  # Additional row for the overall data
fig, axs = plt.subplots(n_rows, 3, figsize=(18, n_rows * 7))
fig.subplots_adjust(hspace=0.6, wspace=0.4)

# Cluster KCC abundance
for i, cluster in enumerate(np.sort(df_merged['Cluster'].unique())):
    ax = axs.flat[i]
    cluster_kcc_abundance = df_merged[df_merged['Cluster'] == cluster]['kcc'].value_counts(normalize=True).sort_index()
    
    cluster_kcc_abundance.plot(kind='bar', ax=ax, color=sns.color_palette("viridis", len(cluster_kcc_abundance)))
    cluster_label = 'Noise' if cluster == -1 else f'Cluster {cluster+1}'
    ax.set_title(f'{cluster_label} - KCC Proportion')
    ax.set_ylabel('Proportion')
    ax.set_ylim(0, 1.2)
    add_labels(ax, cluster_kcc_abundance.values)

# Overall KCC abundance
ax = axs.flat[n_clusters]
overall_kcc_abundance = df['kcc'].value_counts(normalize=True).sort_index()
overall_kcc_abundance.plot(kind='bar', ax=ax, color=sns.color_palette("viridis", len(overall_kcc_abundance)))
ax.set_title('Overall - KCC Proportion')
ax.set_ylabel('Proportion')
ax.set_ylim(0, 1.2)
add_labels(ax, overall_kcc_abundance.values)

for i in range(n_clusters + 1, n_rows * 3):
    if i < len(axs.flat):
        fig.delaxes(axs.flat[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Visualize as heatmaps

# %%
continent_cluster_proportion = pd.crosstab(df_merged['Cluster'], df_merged['Continent'], normalize='index')
plt.figure(figsize=(10, 8))
sns.heatmap(continent_cluster_proportion, annot=True, cmap='viridis', fmt=".2f")
plt.title('Relative Abundance of Continents in Each Cluster')
plt.xlabel('Continent')
plt.ylabel('Cluster')
plt.show()

# %%
kcc_cluster_proportion = pd.crosstab(df_merged['Cluster'], df_merged['kcc'], normalize='index')
plt.figure(figsize=(12, 12))
sns.heatmap(kcc_cluster_proportion, annot=True, cmap='viridis', fmt=".2f")
plt.title('Relative Abundance of KCCs in Each Cluster')
plt.xlabel('KCC')
plt.ylabel('Cluster')
plt.show()

# %% [markdown]
# Visualization of geographic spread (Latitude, Longitude) for each cluster

# %%
plt.figure(figsize=(14, 12))
sns.boxplot(x='Cluster', y='NumericLatitude', data=df_merged)

# Ensure you account for the noise cluster (-1) if present
unique_clusters = np.sort(df_merged['Cluster'].unique())
for cluster in unique_clusters:
    cluster_latitudes = df_merged[df_merged['Cluster'] == cluster]['NumericLatitude']
    percentiles = np.percentile(cluster_latitudes, [25, 50, 75])  # Q1, Median, Q3
    lower_whisker = np.min(cluster_latitudes[cluster_latitudes >= percentiles[0] - 1.5*(percentiles[2]-percentiles[0])])
    upper_whisker = np.max(cluster_latitudes[cluster_latitudes <= percentiles[2] + 1.5*(percentiles[2]-percentiles[0])])
    
    cluster_index = np.where(unique_clusters == cluster)[0][0]  # Find the index of the cluster for plotting
    plt.text(cluster_index, lower_whisker, f'{lower_whisker:.2f}', ha='center', va='top', fontsize=9, color='blue')
    plt.text(cluster_index, percentiles[0], f'{percentiles[0]:.2f}', ha='center', va='top', fontsize=9, color='blue')
    plt.text(cluster_index, percentiles[1], f'{percentiles[1]:.2f}', ha='center', va='center', fontsize=9, color='white')
    plt.text(cluster_index, percentiles[2], f'{percentiles[2]:.2f}', ha='center', va='bottom', fontsize=9, color='blue')
    plt.text(cluster_index, upper_whisker, f'{upper_whisker:.2f}', ha='center', va='bottom', fontsize=9, color='blue')

plt.title('Geographical Spread by Latitude (N/S)')
plt.ylabel('NumericLatitude')
plt.xlabel('Cluster')
plt.xticks(rotation=45)  # Ensure cluster labels are readable
plt.show()

plt.figure(figsize=(14, 12))
sns.boxplot(x='Cluster', y='NumericLongitude', data=df_merged)

for cluster in unique_clusters:
    cluster_longitudes = df_merged[df_merged['Cluster'] == cluster]['NumericLongitude']
    percentiles = np.percentile(cluster_longitudes, [25, 50, 75])
    lower_whisker = np.min(cluster_longitudes[cluster_longitudes >= percentiles[0] - 1.5*(percentiles[2]-percentiles[0])])
    upper_whisker = np.max(cluster_longitudes[cluster_longitudes <= percentiles[2] + 1.5*(percentiles[2]-percentiles[0])])
    
    cluster_index = np.where(unique_clusters == cluster)[0][0]
    plt.text(cluster_index, lower_whisker, f'{lower_whisker:.2f}', ha='center', va='top', fontsize=9, color='blue')
    plt.text(cluster_index, percentiles[0], f'{percentiles[0]:.2f}', ha='center', va='top', fontsize=9, color='blue')
    plt.text(cluster_index, percentiles[1], f'{percentiles[1]:.2f}', ha='center', va='center', fontsize=9, color='white')
    plt.text(cluster_index, percentiles[2], f'{percentiles[2]:.2f}', ha='center', va='bottom', fontsize=9, color='blue')
    plt.text(cluster_index, upper_whisker, f'{upper_whisker:.2f}', ha='center', va='bottom', fontsize=9, color='blue')

plt.title('Geographical Spread by Longitude (E/W)')
plt.ylabel('NumericLongitude')
plt.xlabel('Cluster')
plt.xticks(rotation=45)
plt.show()
